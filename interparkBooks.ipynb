# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilrong/colab-playground/blob/master/interparkBooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interpark Books Open API
# ## 목적
# Manazoom 만화 데이터 수집을 위해서 인터파크 도서 API를 CSV 파일로 변환

# %%
import requests 
import json
import csv
import pandas as pd

apiKey = "6BA2D2EF24CEC77DBB95FD66C9FCE205169F20EA40F5ACF8BD9A0145AB261F21"
# 만화 카테고리
categoryId = "108"
url = "http://book.interpark.com/api/bestSeller.api?key=" + apiKey + "&categoryId=" + categoryId + "&output=json"

req = requests.get(url) 
json = req.json()

data = pd.DataFrame(json['item'])
#data.head()
data[['title', 'description', 'pubDate', 'coverLargeUrl', 'categoryName', 'publisher', 'author', 'isbn', 'link']]
#data.to_csv('./bestBooks.csv', header=False, index=False)
# Out:
#                                   title  ...                                               link
# 0                             귀멸의 칼날 19  ...  http://book.interpark.com/blog/integration/pro...
# 1                                원피스 96  ...  http://book.interpark.com/blog/integration/pro...
# 2                                여름 안에서  ...  http://book.interpark.com/blog/integration/pro...
# 3                              하이큐!! 42  ...  http://book.interpark.com/blog/integration/pro...
# 4                어느 날 공주가 되어버렸다 4 (일반판)  ...  http://book.interpark.com/blog/integration/pro...
# 5                            드래곤볼 슈퍼 12  ...  http://book.interpark.com/blog/integration/pro...
# 6                          지박소년 하나코 군 9  ...  http://book.interpark.com/blog/integration/pro...
# 7                         란마 1/2 애장판 11  ...  http://book.interpark.com/blog/integration/pro...
# 8                         지박소년 하나코 군 10  ...  http://book.interpark.com/blog/integration/pro...
# ...
